# %%
from selenium import webdriver

# %%
# pip install selenium
# pip install beautifulsoup4
# pip install pandas

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: FCCC-D050
#
#  C:\PycharmProject\scrapping\practice 디렉터리
#
# 2021-09-09  오전 09:12        11,177,472 chromedriver.exe
#                1개 파일          11,177,472 바이트
#                0개 디렉터리  79,586,004,992 바이트 남음

# %%
browser = webdriver.Chrome('./chromedriver.exe')

# %%
browser.get('https://www.10000recipe.com/recipe/list.html?q=감자')

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(browser.page_source,'html.parser')

# %%
pages = soup.select('ul.rcp_m_list2')

# %%
pages[0]
# Out:
# <ul class="rcp_m_list2">
# <div class="m_list_tit">
#     총 <b>5,961</b>개의 맛있는 레시피가 있습니다.
#     <ul class="nav nav-tabs2 pull-right" style="position:relative;">
# <li role="presentation"><a href="javascript:void(0);" onclick="goSearchRecipe('order','accuracy')">정확순</a></li>
# <li role="presentation"><a href="javascript:void(0);" onclick="goSearchRecipe('order','date')">최신순</a></li>
# <li class="active" role="presentation"><a href="javascript:void(0);" onclick="goSearchRecipe('order','reco')">추천순</a></li>
# </ul>
# </div>
# <ul class="common_sp_list_ul ea4" style="padding:0 0 0 8px;">
# <li class="common_sp_list_li">
# <div class="common_sp_thumb">
# <a class="common_sp_link" href="/recipe/6871953">
# <img src="https://recipe1.ezmember.co.kr/cache/recipe/2017/06/29/859353599938ad5c66b4803ea56509541_m.jpg"/>
# </a>
# </div>
# <div class="common_sp_caption">
# <div class="common_sp_caption_tit line2">【스팸감자볶음만들기】</div>
# ...

# %%
page = pages[0]

# %%
part = page.select('#contents_area_full > ul > ul > li:nth-child(18) > div.common_sp_caption > div.common_sp_caption_tit.line2')
len(part)
part , type(part)
# Out:
# ([<div class="common_sp_caption_tit line2">실패없이 만드는 밥도둑 감자스팸간장조림 황금레시피!!</div>],
#  bs4.element.ResultSet)

# %%
title = part[0].text.strip()

title
# Out:
# '실패없이 만드는 밥도둑 감자스팸간장조림 황금레시피!!'

# %%
price = part[0].text.strip()

price
# Out:
# '실패없이 만드는 밥도둑 감자스팸간장조림 황금레시피!!'
